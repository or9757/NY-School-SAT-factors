# %%
#import all the files and read the files
import pandas as pd
data_files = [
    "ap_2010.csv",
    "class_size.csv",
    "demographics.csv",
    "graduation.csv",
    "hs_directory.csv",
    "sat_results.csv"
]
data = {}

for i in data_files:
    file = pd.read_csv('./{0}'.format(i))
    key_name = i.replace('.csv', '')
    data[key_name] = file

# %%
print(data['sat_results'].head(5))
# Out:
#       DBN                                    SCHOOL NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL
# 3  01M458                      FORSYTH SATELLITE ACADEMY
# 4  01M509                        MARTA VALLE HIGH SCHOOL
#
#   Num of SAT Test Takers SAT Critical Reading Avg. Score SAT Math Avg. Score  \
# 0                     29                             355                 404
# 1                     91                             383                 423
# 2                     70                             377                 402
# 3                      7                             414                 401
# 4                     44                             390                 433
#
#   SAT Writing Avg. Score
# 0                    363
# 1                    366
# 2                    370
# 3                    359
# 4                    384

# %%
for i in data:
    print(data[i].head(5))
# Out:
#       DBN                             SchoolName  AP Test Takers   \
# 0  01M448           UNIVERSITY NEIGHBORHOOD H.S.             39.0
# 1  01M450                 EAST SIDE COMMUNITY HS             19.0
# 2  01M515                    LOWER EASTSIDE PREP             24.0
# 3  01M539         NEW EXPLORATIONS SCI,TECH,MATH            255.0
# 4  02M296  High School of Hospitality Management              NaN
#
#    Total Exams Taken  Number of Exams with scores 3 4 or 5
# 0               49.0                                  10.0
# 1               21.0                                   NaN
# 2               26.0                                  24.0
# 3              377.0                                 191.0
# 4                NaN                                   NaN
#    CSD BOROUGH SCHOOL CODE                SCHOOL NAME GRADE  PROGRAM TYPE  \
# 0    1       M        M015  P.S. 015 Roberto Clemente     0K       GEN ED
# ...

# %%
#read text file and merge
all_survey = pd.read_csv('./survey_all.txt', delimiter = "\t", encoding = "windows-1252")

d75_survey = pd.read_csv('./survey_d75.txt', delimiter = "\t", encoding = "windows-1252")

survey = pd.concat([all_survey,d75_survey], axis= 0)

survey.shape
# Out:
# (1702, 2773)

# %%
#change 'dbn' columns to 'DBN' in order to consistent. 
survey['DBN'] = survey['dbn']

survey_fields = ["DBN", "rr_s", "rr_t", "rr_p", "N_s", "N_t", "N_p", "saf_p_11", "com_p_11", "eng_p_11", "aca_p_11", "saf_t_11", "com_t_11", "eng_t_11", "aca_t_11", "saf_s_11", "com_s_11", "eng_s_11", "aca_s_11", "saf_tot_11", "com_tot_11", "eng_tot_11", "aca_tot_11"]

survey = survey.loc[:,survey_fields]
#make a new data file
data['survey'] = survey

# %%
data['survey']
# Out:
#        DBN  rr_s  rr_t  rr_p    N_s   N_t    N_p  saf_p_11  com_p_11  \
# 0   01M015   NaN    88    60    NaN  22.0   90.0       8.5       7.6
# 1   01M019   NaN   100    60    NaN  34.0  161.0       8.4       7.6
# 2   01M020   NaN    88    73    NaN  42.0  367.0       8.9       8.3
# 3   01M034  89.0    73    50  145.0  29.0  151.0       8.8       8.2
# 4   01M063   NaN   100    60    NaN  23.0   90.0       8.7       7.9
# ..     ...   ...   ...   ...    ...   ...    ...       ...       ...
# 51  75X352  90.0    58    48   38.0  46.0  160.0       8.9       8.3
# 52  75X721  84.0    90    48  237.0  82.0  239.0       8.6       7.6
# 53  75X723  77.0    74    20  103.0  69.0   74.0       8.4       7.8
# 54  75X754  63.0    93    22  336.0  82.0  124.0       8.3       7.5
# 55  75X811  38.0    63    19   44.0  71.0  119.0       8.5       7.8
#
#     eng_p_11  ...  eng_t_11  aca_t_11  saf_s_11  com_s_11  eng_s_11  aca_s_11  \
# ...

# %%
#make 'dbn' columns to 'DBN' columns 
data['hs_directory']['DBN'] = data['hs_directory']['dbn']

#zfill method is fill zeros till they meet the index
def pad_csd(num):
    return str(num).zfill(2)

# modify CSD columns to put zeros and put it into new columns 'padded_csd'
data['class_size']['padded_csd'] = data['class_size']['CSD'].apply(pad_csd)
#modify 'DBN' columns in 'class_size' file that combined 'padded_csd' and 'SCHOOL CODE'
data['class_size']['DBN'] = data['class_size']['padded_csd'] + data['class_size']['SCHOOL CODE']

# %%
# change data type to number using pd.to_numeric
data['sat_results']['SAT Math Avg. Score'] = pd.to_numeric(data['sat_results']['SAT Math Avg. Score'], errors = 'coerce')

data['sat_results']['SAT Critical Reading Avg. Score'] = pd.to_numeric(data['sat_results']['SAT Critical Reading Avg. Score'], errors = 'coerce')

data['sat_results']['SAT Writing Avg. Score'] = pd.to_numeric(data['sat_results']['SAT Writing Avg. Score'], errors = 'coerce')

#combined all three scores to calculate total score 
data['sat_results']['sat_score'] = data['sat_results']['SAT Math Avg. Score']+data['sat_results']['SAT Critical Reading Avg. Score']+data['sat_results']['SAT Writing Avg. Score']


data['sat_results']['sat_score'].head()
# Out:
# 0    1122.0
# 1    1172.0
# 2    1149.0
# 3    1174.0
# 4    1207.0
# Name: sat_score, dtype: float64

# %%
import re

#method to get latitude from the columns 
def get_latitude(str_):
    pattern = r'\(.+\)'
    coordinates = re.findall(pattern,str_)
    lat = coordinates[0].split(",")[0].replace("(",'')
    coordinates
    return lat

data['hs_directory']['lat'] = data['hs_directory']['Location 1'].apply(get_latitude)

data['hs_directory']['lat'].head()
# Out:
# 0    40.589238098
# 1    40.685451806
# 2    40.744149536
# 3    40.815230365
# 4    40.601989336
# Name: lat, dtype: object

# %%
import re
#method to get longitude from the columns 

def get_longitude(str_):
    pattern = r'\(.+\)'
    coordinates = re.findall(pattern,str_)
    lon = coordinates[0].split(',')[1].replace(')','')
    return lon

data['hs_directory']['lon'] = data['hs_directory']['Location 1'].apply(get_longitude)
data['hs_directory']['lon']
#change data type to numeric 
data['hs_directory']['lon']=pd.to_numeric(data['hs_directory']['lon'], errors = 'coerce')
data['hs_directory']['lat']=pd.to_numeric(data['hs_directory']['lat'], errors = 'coerce')

data['hs_directory'].head()
# Out:
#       dbn                                        school_name    borough  \
# 0  21K540                             John Dewey High School   Brooklyn
# 1  15K429                 Brooklyn School for Global Studies   Brooklyn
# 2  24Q530  International High School at LaGuardia Communi...     Queens
# 3  05M367  Academy for Social Action: A College Board School  Manhattan
# 4  27Q260          Frederick Douglass Academy VI High School     Queens
#
#   building_code  phone_number    fax_number  grade_span_min  grade_span_max  \
# 0          K540  718-373-6400  718-266-4385             9.0              12
# 1          K293  718-694-9741  718-694-9745             6.0              12
# 2          Q520  718-392-3433  718-392-3443             9.0              12
# 3          M043  212-234-3102  212-234-8597             9.0              12
# 4          Q465  718-471-2154  718-471-2890             9.0              12
#
#    expgrade_span_min  expgrade_span_max  ...  \
# ...

# %%
class_size = data['class_size']

#modify class_size file and choose the row that contains "GRADE" is equal to 09-12, because we need only high school information
class_size = class_size[class_size['GRADE '] == '09-12']
#choose the row that contains "PROGRAM TYPE" is equal to "GEN ED"
class_size = class_size[class_size['PROGRAM TYPE'] == 'GEN ED']

class_size.head(5)
# Out:
#      CSD BOROUGH SCHOOL CODE                                    SCHOOL NAME  \
# 225    1       M        M292  Henry Street School for International Studies
# 226    1       M        M292  Henry Street School for International Studies
# 227    1       M        M292  Henry Street School for International Studies
# 228    1       M        M292  Henry Street School for International Studies
# 229    1       M        M292  Henry Street School for International Studies
#
#     GRADE  PROGRAM TYPE CORE SUBJECT (MS CORE and 9-12 ONLY)  \
# 225  09-12       GEN ED                              ENGLISH
# 226  09-12       GEN ED                              ENGLISH
# 227  09-12       GEN ED                              ENGLISH
# 228  09-12       GEN ED                              ENGLISH
# 229  09-12       GEN ED                                 MATH
#
#     CORE COURSE (MS CORE and 9-12 ONLY) SERVICE CATEGORY(K-9* ONLY)  \
# 225                           English 9                           -
# ...

# %%
import numpy as np
#group by "DBN" using mean value of each DBN
grouped = class_size.groupby('DBN')

class_size = grouped.aggregate(np.mean)

#make DBN as columns instead of index
class_size.reset_index(inplace = True)
data['class_size'] = class_size
data['class_size'].head()
# Out:
#       DBN  CSD  NUMBER OF STUDENTS / SEATS FILLED  NUMBER OF SECTIONS  \
# 0  01M292    1                            88.0000            4.000000
# 1  01M332    1                            46.0000            2.000000
# 2  01M378    1                            33.0000            1.000000
# 3  01M448    1                           105.6875            4.750000
# 4  01M450    1                            57.6000            2.733333
#
#    AVERAGE CLASS SIZE  SIZE OF SMALLEST CLASS  SIZE OF LARGEST CLASS  \
# 0           22.564286                   18.50              26.571429
# 1           22.000000                   21.00              23.500000
# 2           33.000000                   33.00              33.000000
# 3           22.231250                   18.25              27.062500
# 4           21.200000                   19.40              22.866667
#
#    SCHOOLWIDE PUPIL-TEACHER RATIO
# 0                             NaN
# 1                             NaN
# ...

# %%
data['class_size'].shape
# Out:
# (583, 8)

# %%
#modify demographics data that contains 'schoolyear' is equal to 20112012
data['demographics']=data['demographics'][data['demographics']['schoolyear'] == 20112012]

data['demographics'].head()
# Out:
#        DBN                                              Name  schoolyear  \
# 6   01M015  P.S. 015 ROBERTO CLEMENTE                           20112012
# 13  01M019  P.S. 019 ASHER LEVY                                 20112012
# 20  01M020  PS 020 ANNA SILVER                                  20112012
# 27  01M034  PS 034 FRANKLIN D ROOSEVELT                         20112012
# 35  01M063  PS 063 WILLIAM MCKINLEY                             20112012
#
#    fl_percent  frl_percent  total_enrollment prek    k grade1 grade2  ...  \
# 6         NaN         89.4               189   13   31     35     28  ...
# 13        NaN         61.5               328   32   46     52     54  ...
# 20        NaN         92.5               626   52  102    121     87  ...
# 27        NaN         99.7               401   14   34     38     36  ...
# 35        NaN         78.9               176   18   20     30     21  ...
#
#    black_num black_per hispanic_num hispanic_per white_num white_per male_num  \
# ...

# %%
#modify 'graduation' file that cohort is equal to 2006
data['graduation']=data['graduation'][data['graduation']['Cohort'] == '2006']
#modify 'graduation' file that demograhic coloumns value is equal to 'Total Cohort'
data['graduation'] = data['graduation'][data['graduation']['Demographic'] == 'Total Cohort']

data['graduation'].head()
# Out:
#      Demographic     DBN                            School Name Cohort  \
# 3   Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL   2006
# 10  Total Cohort  01M448    UNIVERSITY NEIGHBORHOOD HIGH SCHOOL   2006
# 17  Total Cohort  01M450             EAST SIDE COMMUNITY SCHOOL   2006
# 24  Total Cohort  01M509                MARTA VALLE HIGH SCHOOL   2006
# 31  Total Cohort  01M515  LOWER EAST SIDE PREPARATORY HIGH SCHO   2006
#
#     Total Cohort Total Grads - n  Total Grads - % of cohort Total Regents - n  \
# 3             78              43                       55.1                36
# 10           124              53                       42.7                42
# 17            90              70                       77.8                67
# 24            84              47                       56.0                40
# 31           193             105                       54.4                91
#
#     Total Regents - % of cohort  Total Regents - % of grads  ...  \
# ...

# %%
#change columns data type to numeric
cols = ['AP Test Takers ', 'Total Exams Taken', 'Number of Exams with scores 3 4 or 5']

for i in cols:
    data['ap_2010'][i] = pd.to_numeric(data['ap_2010'][i], errors = 'coerce')

data['ap_2010'][cols].dtypes
# Out:
# AP Test Takers                          float64
# Total Exams Taken                       float64
# Number of Exams with scores 3 4 or 5    float64
# dtype: object

# %%
#merge 'sat_result' and 'ap_2010' on DBN 
combined = data["sat_results"].merge(data['ap_2010'], on = 'DBN', how = 'left')
##merge 'sat_result' and 'graduation'
combined = combined.merge(data['graduation'], how = 'left')

combined.head()
# Out:
#       DBN                                    SCHOOL NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL
# 3  01M458                      FORSYTH SATELLITE ACADEMY
# 4  01M509                        MARTA VALLE HIGH SCHOOL
#
#   Num of SAT Test Takers  SAT Critical Reading Avg. Score  \
# 0                     29                            355.0
# 1                     91                            383.0
# 2                     70                            377.0
# 3                      7                            414.0
# 4                     44                            390.0
#
#    SAT Math Avg. Score  SAT Writing Avg. Score  sat_score  \
# 0                404.0                   363.0     1122.0
# 1                423.0                   366.0     1172.0
# 2                402.0                   370.0     1149.0
# ...

# %%
combined.shape
# Out:
# (479, 33)

# %%
#merge all the data to combined
dfs = ["class_size", "demographics", "survey", "hs_directory"]
for i in dfs:
    combined = combined.merge(data[i],  on = 'DBN',how = 'inner',)

# %%
combined.head()
# Out:
#       DBN                                        SCHOOL NAME  \
# 0  01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                         EAST SIDE COMMUNITY SCHOOL
# 3  01M509                            MARTA VALLE HIGH SCHOOL
# 4  01M539  NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND ...
#
#   Num of SAT Test Takers  SAT Critical Reading Avg. Score  \
# 0                     29                            355.0
# 1                     91                            383.0
# 2                     70                            377.0
# 3                     44                            390.0
# 4                    159                            522.0
#
#    SAT Math Avg. Score  SAT Writing Avg. Score  sat_score  \
# 0                404.0                   363.0     1122.0
# 1                423.0                   366.0     1172.0
# 2                402.0                   370.0     1149.0
# ...

# %%
combined.shape
# Out:
# (363, 165)

# %%
#get mean value of each columns
mean = combined.mean()
#fill NaN value to mean value
combined = combined.fillna(mean)

#if there is non-numeric columns, change to 0
combined= combined.fillna(0)

combined.head()
# Out:
#       DBN                                        SCHOOL NAME  \
# 0  01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                         EAST SIDE COMMUNITY SCHOOL
# 3  01M509                            MARTA VALLE HIGH SCHOOL
# 4  01M539  NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND ...
#
#   Num of SAT Test Takers  SAT Critical Reading Avg. Score  \
# 0                     29                            355.0
# 1                     91                            383.0
# 2                     70                            377.0
# 3                     44                            390.0
# 4                    159                            522.0
#
#    SAT Math Avg. Score  SAT Writing Avg. Score  sat_score  \
# 0                404.0                   363.0     1122.0
# 1                423.0                   366.0     1172.0
# 2                402.0                   370.0     1149.0
# ...

# %%
def first_two_char(str_):
    return str_[:2]
#take 'school_dist value' from 'DBN's first two string
combined['school_dist']=combined['DBN'].apply(first_two_char)

combined['school_dist'].head()
# Out:
# 0    01
# 1    01
# 2    01
# 3    01
# 4    01
# Name: school_dist, dtype: object

# %%
#get correlations of sat_score to other columns in combined data
#sat_score vs [all_other_columns]
correlations = combined.corr()
correlations= correlations['sat_score']

# %%
print(correlations)
# Out:
# SAT Critical Reading Avg. Score    0.986820
# SAT Math Avg. Score                0.972643
# SAT Writing Avg. Score             0.987771
# sat_score                          1.000000
# AP Test Takers                     0.523140
#                                      ...
# Census Tract                       0.048737
# BIN                                0.052232
# BBL                                0.044427
# lat                               -0.121029
# lon                               -0.132222
# Name: sat_score, Length: 85, dtype: float64

# %%
survey_fields.remove("DBN")

# %%
#make correlations to bar graph
# %matplotlib inline
combined.corr()['sat_score'][survey_fields].plot.bar()

#rr_t and com_p_11 has negative relationship

#rr_s, N_s, N_t, N_p, saf_s_ll are positive
#more total enrollment has higher sat_score 
#if student feels safe, they would have higher SAT score

#Total Enrollment and Safety are the key to have higher SAT score

# %%
import matplotlib.pyplot as plt

combined.plot.scatter(x = 'total_enrollment', y = 'sat_score', title = 'Total Enrollment impacts on SAT score')

#Shows that how total enrollment impacts on SAT score

# %%
#select low_enrollment from combined data. 
low_enrollment = combined[combined['total_enrollment'] < 1000]
#select low scores in low_enrollment
low_enrollment = low_enrollment[low_enrollment['sat_score'] < 1000]

low_enrollment['School Name']

#get schools name which are low enrollment and low scores on SAT
# Out:
# 91       INTERNATIONAL COMMUNITY HIGH SCHOOL
# 125                                        0
# 126          BRONX INTERNATIONAL HIGH SCHOOL
# 139    KINGSBRIDGE INTERNATIONAL HIGH SCHOOL
# 141    INTERNATIONAL SCHOOL FOR LIBERAL ARTS
# 176                                        0
# 179            HIGH SCHOOL OF WORLD CULTURES
# 188       BROOKLYN INTERNATIONAL HIGH SCHOOL
# 225    INTERNATIONAL HIGH SCHOOL AT PROSPECT
# 237               IT TAKES A VILLAGE ACADEMY
# 253                MULTICULTURAL HIGH SCHOOL
# 286    PAN AMERICAN INTERNATIONAL HIGH SCHOO
# Name: School Name, dtype: object

# %%
combined.plot.scatter(x = 'ell_percent', y = 'sat_score', title = 'English Learner percent in each school vs sat_ score')


#how English Learner percentage have impact on school's SAT score
#clearly shows that lot of ell_percent brings low score on SAT 
#(See right bottom of the graph)

# %%
import os
os.environ["PROJ_LIB"] = "C:/Users/ryans/Anaconda3/Library/share"; #fixr
from mpl_toolkits.basemap import Basemap

# %%
from mpl_toolkits.basemap import Basemap

# %%
from mpl_toolkits.basemap import Basemap

m = Basemap(
    projection='merc', 
    llcrnrlat=40.496044, 
    urcrnrlat=40.915256, 
    llcrnrlon=-74.255735, 
    urcrnrlon=-73.700272,
    resolution='i'
)

m.drawmapboundary(fill_color='#85A6D9')
m.drawcoastlines(color='#6D5F47', linewidth=.4)
m.drawrivers(color='#6D5F47', linewidth=.4)

longitudes = combined['lon'].tolist()

latitudes = combined['lat'].tolist()

m.scatter(longitudes, latitudes, s = 20, zorder = 2, latlon = True)
plt.show()

#put circle to map of schools

# %%
from mpl_toolkits.basemap import Basemap

m = Basemap(
    projection='merc', 
    llcrnrlat=40.496044, 
    urcrnrlat=40.915256, 
    llcrnrlon=-74.255735, 
    urcrnrlon=-73.700272,
    resolution='i'
)

m.drawmapboundary(fill_color='#85A6D9')
m.drawcoastlines(color='#6D5F47', linewidth=.4)
m.drawrivers(color='#6D5F47', linewidth=.4)

longitudes = combined["lon"].tolist()
latitudes = combined["lat"].tolist()
m.scatter(longitudes, latitudes, s = 20, zorder =2, latlon = True, c = combined['ell_percent'], cmap = 'summer')

plt.show()

# %%
# group by school_dist and get mean value of each districts
import numpy as np

districts = combined.groupby('school_dist').agg(np.mean)

districts.reset_index(inplace = True)

districts.head()
# Out:
#   school_dist  SAT Critical Reading Avg. Score  SAT Math Avg. Score  \
# 0          01                       441.833333           473.333333
# 1          02                       426.619092           444.186256
# 2          03                       428.529851           437.997512
# 3          04                       402.142857           416.285714
# 4          05                       427.159915           438.236674
#
#    SAT Writing Avg. Score    sat_score  AP Test Takers   Total Exams Taken  \
# 0              439.333333  1354.500000       116.681090         173.019231
# 1              424.832836  1295.638184       128.908454         201.516827
# 2              426.915672  1293.443035       156.183494         244.522436
# 3              405.714286  1224.142857       129.016484         183.879121
# 4              419.666098  1285.062687        85.722527         115.725275
#
#    Number of Exams with scores 3 4 or 5  Total Cohort  \
# ...

# %%
# make a map by districts
from mpl_toolkits.basemap import Basemap

m = Basemap(
    projection='merc', 
    llcrnrlat=40.496044, 
    urcrnrlat=40.915256, 
    llcrnrlon=-74.255735, 
    urcrnrlon=-73.700272,
    resolution='i'
)

m.drawmapboundary(fill_color='#85A6D9')
m.drawcoastlines(color='#6D5F47', linewidth=.4)
m.drawrivers(color='#6D5F47', linewidth=.4)

longitudes = districts["lon"].tolist()
latitudes = districts["lat"].tolist()

m.scatter(longitudes, latitudes, s = 50, zorder = 2, latlon = True, c = districts['ell_percent'], cmap = 'summer')
plt.show()

## Yellow is more safety, and green is dangerous districts.
#According to our data, upper Manhattan is safer than Brooklyn

# %%
racial_col = ['white_per', 'asian_per', 'black_per' ,'hispanic_per']

combined.corr()['sat_score'][racial_col].plot.bar(title = 'sat score by race')

#white and asian has higher score in SAT
#black and hispanic has lower in SAT

# %%
#get mean of sat_score of all New York Schools
combined['sat_score'].mean() #1223
#modify data that has lower sat_score than 1200
low_score_combined = combined[combined['sat_score'] < 1200]
#modify data that hispanic percentatge is higher than 70%
low_score_high_his_combined=low_score_combined[low_score_combined['hispanic_per']>70.0]

#bring 'School Name', 'SAT SCORE','hispanic percentage'
low_score_high_his_combined[['SCHOOL NAME', 'sat_score', 'hispanic_per']]
#table with school name, sat score(lower than average) and hispanic percentage that is higher than 70
# Out:
#                                            SCHOOL NAME  sat_score  \
# 12                          FACING HISTORY SCHOOL, THE     1051.0
# 28                                LANDMARK HIGH SCHOOL     1170.0
# 44                       MANHATTAN BRIDGES HIGH SCHOOL     1058.0
# 81             COMMUNITY HEALTH ACADEMY OF THE HEIGHTS     1105.0
# 82    WASHINGTON HEIGHTS EXPEDITIONARY LEARNING SCHOOL     1174.0
# 84   HIGH SCHOOL FOR INTERNATIONAL BUSINESS AND FIN...     1127.0
# 85            HIGH SCHOOL FOR MEDIA AND COMMUNICATIONS     1098.0
# 86              HIGH SCHOOL FOR LAW AND PUBLIC SERVICE     1102.0
# 89   GREGORIO LUPERON HIGH SCHOOL FOR SCIENCE AND M...     1014.0
# 91                 INTERNATIONAL COMMUNITY HIGH SCHOOL      945.0
# 93          MOTT HAVEN VILLAGE PREPARATORY HIGH SCHOOL     1097.0
# 99         URBAN ASSEMBLY SCHOOL FOR CAREERS IN SPORTS     1181.0
# 112  FELISA RINCON DE GAUTIER INSTITUTE FOR LAW AND...     1099.0
# ...

# %%
#combined.plot.scatter(x = 'hispanic_per', y = 'sat_score', title = 'hispanic vs sat score')

import seaborn as sns
ax = sns.lmplot(x='hispanic_per',y='sat_score',data=combined,fit_reg=True) 
plt.title('Hispanic percentage vs SAT Score')

#linear line could be estimated with negative slope.
#it shows lower hispanic rate has higher sat score and vise versa
# Out:
# Text(0.5, 1, 'Hispanic percentage vs SAT Score')

# %%
#schools that consist of over 95% of hispanic
high_his_combined=combined[combined['hispanic_per']>95.0]

high_his_combined[['SCHOOL NAME', 'sat_score', 'hispanic_per']]

#list of school name that has over 95 percent of hispanic race
# Out:
#                                            SCHOOL NAME  sat_score  \
# 44                       MANHATTAN BRIDGES HIGH SCHOOL     1058.0
# 82    WASHINGTON HEIGHTS EXPEDITIONARY LEARNING SCHOOL     1174.0
# 89   GREGORIO LUPERON HIGH SCHOOL FOR SCIENCE AND M...     1014.0
# 125                ACADEMY FOR LANGUAGE AND TECHNOLOGY      951.0
# 141              INTERNATIONAL SCHOOL FOR LIBERAL ARTS      934.0
# 176   PAN AMERICAN INTERNATIONAL HIGH SCHOOL AT MONROE      970.0
# 253                          MULTICULTURAL HIGH SCHOOL      887.0
# 286             PAN AMERICAN INTERNATIONAL HIGH SCHOOL      951.0
#
#      hispanic_per
# 44           99.8
# 82           96.7
# 89           99.8
# 125          99.4
# 141          99.8
# 176          99.8
# 253          99.8
# 286         100.0

# %%
#schools that consist of less than 10% of hispanic
low_his_combined=combined[combined['hispanic_per']<10.0]
low_his_avg_sat_combined = low_his_combined[low_his_combined['sat_score'] > 1800]

low_his_avg_sat_combined[['SCHOOL NAME', 'sat_score', 'hispanic_per']]

#result is interesting. schools are focused on science and technology fields have higher sat scores
# Out:
#                                            SCHOOL NAME  sat_score  \
# 37                              STUYVESANT HIGH SCHOOL     2096.0
# 151                       BRONX HIGH SCHOOL OF SCIENCE     1969.0
# 187                     BROOKLYN TECHNICAL HIGH SCHOOL     1833.0
# 327  QUEENS HIGH SCHOOL FOR THE SCIENCES AT YORK CO...     1868.0
# 356                STATEN ISLAND TECHNICAL HIGH SCHOOL     1953.0
#
#      hispanic_per
# 37            2.4
# 151           7.2
# 187           7.9
# 327           7.9
# 356           5.3

# %%
combined.corr()['sat_score'][['female_per','male_per']].plot.bar()
#female gets higher score than males

# %%
combined.plot.scatter(x = 'female_per', y = 'sat_score', title = 'female_per vs sat_score')

# school that has 50% of female has higher score than other schools 
# Although female students have higher score than male score, that does not mean, only female students do well in the test 
# schools which are only female students are in has lower sat score
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
    combined['ap_per'] = (combined['AP Test Takers '] / combined['total_enrollment'])*100

    combined
# Out:
#         DBN                                        SCHOOL NAME  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M509                            MARTA VALLE HIGH SCHOOL
# 4    01M539  NEW EXPLORATIONS INTO SCIENCE, TECHNOLOGY AND ...
# ..      ...                                                ...
# 358  32K545        EBC HIGH SCHOOL FOR PUBLIC SERVICE–BUSHWICK
# 359  32K549                 BUSHWICK SCHOOL FOR SOCIAL JUSTICE
# 360  32K552                          ACADEMY OF URBAN PLANNING
# 361  32K554               ALL CITY LEADERSHIP SECONDARY SCHOOL
# 362  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...
#
#     Num of SAT Test Takers  SAT Critical Reading Avg. Score  \
# 0                       29                            355.0
# 1                       91                            383.0
# ...

# %%
combined.plot.scatter(x = 'ap_per', y = 'sat_score', title = 'ap_per vs sat_score')
# Although many people think that if ap_per is high, then sat_score would be high as well 
# However, it does not have strong correlations between AP and SAT
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
